# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np

# %%
# 讀取數據
df = pd.read_csv(r"C:\Users\brigh\uci-secom.csv")
#特徵資料量
df['Pass/Fail'].value_counts()
# Out:
# Pass/Fail
# -1    1463
#  1     104
# Name: count, dtype: int64

# %%
plt.figure( figsize=(10,5) )
df['Pass/Fail'].value_counts().plot( kind='pie', colors=['lightcoral','skyblue'], autopct='%1.2f%%' )
plt.title( 'Pass/Fail' )  # 圖標題
plt.show()
#此資料集(Pass/Fail)比例相當懸殊，我們必須經過處理後才能丟進模型訓練，否則就會發生過度擬合的問題
#而處理方法分為上採樣(OverSampling)以及下採樣(UnderSampling)。

# %%
#下採樣的方法是透過刪除較多的樣本數，使兩個類別的樣本數量達到平衡。
#這樣的方法雖然方便，但其實缺點也很明顯，我們會失去大量的數據。
#以上面半導體的資料集來舉例，我們假如使用下採樣的方法，我們最後的資料集只會有原本的10%，不推薦使用。

#上採樣：
#透過一些方法提升樣本數較少的資料，最常見的方法之一就是SMOTE。
#SMOTE:一種數據合成的方法，概念是在少數樣本附近的位置，"人工合成"出一些樣本。

# %%
#先分出訓練集及測試集
#要先做資料分割的動作的原因是，測試集是為了讓我們檢視最真實的評估結果，因此盡量保留它的完整性，不要去做過多的加工處理。
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3,random_state=11)
right_ratio_x_train, right_ratio_x_test, right_ratio_y_train, right_ratio_y_test = train_test_split(employee, encoded_labels, test_size=0.2, random_state=666)
